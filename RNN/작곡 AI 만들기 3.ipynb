# %%
import tensorflow as tf

p_model = tf.keras.models.load_model('./model1')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-5-8d2b7378d5ad> in <module>
#       1 import tensorflow as tf
#       2
# ----> 3 p_model = tf.keras.models.load_model('./model1')
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\saving\save.py in load_model(filepath, custom_objects, compile, options)
#     185     if isinstance(filepath, six.string_types):
#     186       loader_impl.parse_saved_model(filepath)
# --> 187       return saved_model_load.load(filepath, compile, options)
#     188
#     189   raise IOError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in load(path, compile, options)
#     118   # TODO(kathywu): Add code to load from objects that contain all endpoints
#     119
# --> 120   model = tf_load.load_internal(
# ...
