# %% [markdown]
# # Long Short Term Memory
# 장기 기억 메모리  입력하는 문장이 길어지는 경우 RNN 레이어는 첫 입력값이 희미해지는 문제가 있음 (장기 기억에 대한 문제)
# ### Diminishing Gradient 라고도 함
# 그래서 LSTM 쓰고 비슷한 유사품으로 GRU가 있음
# #### 둘중 결과값 좋은써 쓰면 됨
#
#   ![image.png](attachment:image.png)
