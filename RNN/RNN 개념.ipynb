# %% [markdown]
# # Recurrent Neural Network
#
# ## 순서가 의미 있어지는 딥러닝 학습
#
# RNN을 사용하면 sequence 데이터 입출력 가능
# (sequence 데이터는 순서개념이 있는 데이터)  <br>
#
#   ### 응용
#
# vector to sequence (이미지 자동캡션)
#
#   ![image.png](attachment:image.png)
#
# sequence to vector (글의 감정분석, 악플검사)
#
#   ![image-2.png](attachment:image-2.png)
#
# sequence to sequence (번역) <br>
#
#   ![image-4.png](attachment:image-4.png)
